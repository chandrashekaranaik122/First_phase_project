# %% [markdown]
# # Base_ball_project

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Import all nessasary lybraries such as pandas , numpy, seaborn ,matplot and also imported warnings

# %%
df=pd.read_csv('Base_ball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %% [markdown]
# loading the csv file from my jupyternote book

# %% [markdown]
# -- Input features-
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17.	E - This means Errors.It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# checking for the null values in the dataset...
#
# there is no null values present in the dataset

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# 17 columns are present in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# checking the information of the dataset...
# 17 columns with 30 rows present and all columns numarical values
#
# 16 columns are integer datatype and 1 column float

# %%
for i in df.columns:
    print('======================','\n',
          i,'~ Column',
          '\n','=====================','\n',
          df[i].value_counts())
# Out:
# ======================
#  W ~ Column
#  =====================
#  68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
# ======================
#  R ~ Column
#  =====================
#  689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
# ======================
#  AB ~ Column
#  =====================
#  5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: AB, dtype: int64
# ======================
#  H ~ Column
#  =====================
#  1363    2
# 1497    1
# 1386    1
# 1324    1
# 1494    1
# 1486    1
# 1346    1
# 1374    1
# 1361    1
# 1420    1
# 1351    1
# 1382    1
# 1378    1
# 1341    1
# 1462    1
# 1405    1
# 1349    1
# 1379    1
# 1331    1
# 1419    1
# 1495    1
# 1383    1
# 1370    1
# 1397    1
# 1480    1
# 1515    1
# 1381    1
# 1395    1
# 1479    1
# Name: H, dtype: int64
# ======================
#  2B ~ Column
#  =====================
#  272    3
# 260    2
# 289    2
# 278    2
# 277    2
# 274    2
# 288    2
# 300    1
# 292    1
# 251    1
# 236    1
# 265    1
# 295    1
# 257    1
# 243    1
# 262    1
# 279    1
# 294    1
# 246    1
# 308    1
# 303    1
# 263    1
# Name: 2B, dtype: int64
# ======================
#  3B ~ Column
#  =====================
#  27    3
# 39    2
# 49    2
# 17    2
# 32    2
# 26    2
# 42    1
# 48    1
# 37    1
# 18    1
# 40    1
# 13    1
# 34    1
# 30    1
# 21    1
# 46    1
# 22    1
# 44    1
# 33    1
# 20    1
# 19    1
# 29    1
# 36    1
# Name: 3B, dtype: int64
# ======================
#  HR ~ Column
#  =====================
#  136    2
# 167    2
# 177    2
# 139    1
# 137    1
# 148    1
# 154    1
# 187    1
# 130    1
# 100    1
# 120    1
# 145    1
# 171    1
# 140    1
# 198    1
# 146    1
# 156    1
# 176    1
# 230    1
# 172    1
# 161    1
# 217    1
# 212    1
# 232    1
# 151    1
# 141    1
# 186    1
# Name: HR, dtype: int64
# ======================
#  BB ~ Column
#  =====================
#  478    2
# 383    1
# 461    1
# 426    1
# 490    1
# 457    1
# 563    1
# 387    1
# 471    1
# 375    1
# 539    1
# 488    1
# 496    1
# 412    1
# 567    1
# 506    1
# 439    1
# 475    1
# 435    1
# 486    1
# 503    1
# 436    1
# 418    1
# 554    1
# 570    1
# 455    1
# 404    1
# 533    1
# 388    1
# Name: BB, dtype: int64
# ======================
#  SO ~ Column
#  =====================
#  1150    2
# 973     1
# 1267    1
# 1327    1
# 1312    1
# 1159    1
# 1258    1
# 1274    1
# 1107    1
# 1344    1
# 1290    1
# 1255    1
# 1299    1
# 1518    1
# 1322    1
# 1119    1
# 1264    1
# 1336    1
# 1392    1
# 1233    1
# 1148    1
# 1310    1
# 1331    1
# 1227    1
# 1151    1
# 1259    1
# 1231    1
# 1157    1
# 1283    1
# Name: SO, dtype: int64
# ======================
#  SB ~ Column
#  =====================
#  69     3
# 88     2
# 78     1
# 82     1
# 132    1
# 93     1
# 59     1
# 112    1
# 57     1
# 51     1
# 134    1
# 84     1
# 95     1
# 98     1
# 104    1
# 70     1
# 52     1
# 121    1
# 101    1
# 71     1
# 87     1
# 44     1
# 63     1
# 83     1
# 68     1
# 86     1
# 97     1
# Name: SB, dtype: int64
# ======================
#  RA ~ Column
#  =====================
#  641    1
# 700    1
# 731    1
# 713    1
# 627    1
# 595    1
# 809    1
# 760    1
# 678    1
# 635    1
# 613    1
# 754    1
# 737    1
# 608    1
# 596    1
# 525    1
# 729    1
# 726    1
# 675    1
# 618    1
# 733    1
# 753    1
# 642    1
# 693    1
# 698    1
# 670    1
# 803    1
# 701    1
# 640    1
# 844    1
# Name: RA, dtype: int64
# ======================
#  ER ~ Column
#  =====================
#  601    1
# 653    1
# 655    1
# 659    1
# 597    1
# 553    1
# 749    1
# 698    1
# 638    1
# 577    1
# 557    1
# 700    1
# 682    1
# 546    1
# 532    1
# 478    1
# 664    1
# 677    1
# 630    1
# 572    1
# 680    1
# 694    1
# 604    1
# 646    1
# 652    1
# 609    1
# 746    1
# 643    1
# 584    1
# 799    1
# Name: ER, dtype: int64
# ======================
#  ERA ~ Column
#  =====================
#  3.73    1
# 4.07    1
# 4.09    1
# 4.04    1
# 3.72    1
# 3.44    1
# 4.69    1
# 4.41    1
# 4.02    1
# 3.62    1
# 3.43    1
# 4.33    1
# 4.28    1
# 3.36    1
# 3.21    1
# 2.94    1
# 4.14    1
# 4.16    1
# 3.94    1
# 3.57    1
# 4.24    1
# 4.31    1
# 3.74    1
# 4.05    1
# 4.03    1
# 3.80    1
# 4.64    1
# 3.98    1
# 3.67    1
# 5.04    1
# Name: ERA, dtype: int64
# ======================
#  CG ~ Column
#  =====================
#  1     7
# 2     4
# 7     4
# 3     3
# 0     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: CG, dtype: int64
# ======================
#  SHO ~ Column
#  =====================
#  12    7
# 10    5
# 13    3
# 8     2
# 9     2
# 4     2
# 15    2
# 21    2
# 7     2
# 14    1
# 18    1
# 6     1
# Name: SHO, dtype: int64
# ======================
#  SV ~ Column
#  =====================
#  35    4
# 41    3
# 45    3
# 44    2
# 48    2
# 40    2
# 56    1
# 28    1
# 47    1
# 50    1
# 54    1
# 62    1
# 39    1
# 46    1
# 60    1
# 43    1
# 34    1
# 37    1
# 38    1
# 36    1
# Name: SV, dtype: int64
# ======================
#  E ~ Column
#  =====================
#  88     3
# 90     3
# 86     3
# 93     2
# 77     2
# 95     2
# 122    1
# 78     1
# 75     1
# 117    1
# 116    1
# 111    1
# 94     1
# 96     1
# 126    1
# 85     1
# 119    1
# 97     1
# 101    1
# 79     1
# 92     1
# Name: E, dtype: int64

# %% [markdown]
# all the columns are having the values there is no missing data is present in row and columns

# %%
for i in df.columns:
    print('======================','\n',
          i,'~ Column','\n',
          '======================','\n',
          df[i].unique())
# Out:
# ======================
#  W ~ Column
#  ======================
#  [ 95  83  81  76  74  93  87  80  78  88  86  85  68 100  98  97  64  90
#   71  67  63  92  84  79]
# ======================
#  R ~ Column
#  ======================
#  [724 696 669 622 689 891 764 713 644 748 751 729 661 656 694 647 697 655
#  640 683 703 613 573 626 667 720 650 737]
# ======================
#  AB ~ Column
#  ======================
#  [5575 5467 5439 5533 5605 5509 5567 5485 5640 5511 5459 5417 5544 5600
#  5484 5631 5491 5480 5571 5527 5428 5463 5420 5529 5385 5565 5649 5457
#  5572]
# ======================
#  H ~ Column
#  ======================
#  [1497 1349 1395 1381 1515 1480 1397 1370 1383 1495 1419 1363 1331 1379
#  1405 1386 1462 1341 1378 1382 1351 1420 1361 1374 1346 1486 1494 1324
#  1479]
# ======================
#  2B ~ Column
#  ======================
#  [300 277 303 260 289 308 272 246 278 294 279 243 262 288 292 274 257 295
#  265 236 251 263]
# ======================
#  3B ~ Column
#  ======================
#  [42 44 29 27 49 17 19 20 32 33 26 21 22 46 39 30 34 13 40 18 37 48 36]
# ======================
#  HR ~ Column
#  ======================
#  [139 156 141 136 151 232 212 217 167 161 172 230 176 198 146 137 140 171
#  145 177 120 100 130 187 154 148 186]
# ======================
#  BB ~ Column
#  ======================
#  [383 439 533 404 455 570 554 418 436 478 503 486 435 475 506 461 567 412
#  496 488 539 375 471 387 563 457 490 426 388]
# ======================
#  SO ~ Column
#  ======================
#  [ 973 1264 1157 1231 1259 1151 1227 1331 1310 1148 1233 1392 1150 1336
#  1119 1267 1322 1518 1299 1255 1290 1344 1107 1274 1258 1159 1312 1327
#  1283]
# ======================
#  SB ~ Column
#  ======================
#  [104  70  86  68  83  88  63  44  87  71 101 121  52  69  78  98  95  84
#  134  51  57 112  59  93 132  82  97]
# ======================
#  RA ~ Column
#  ======================
#  [641 700 640 701 803 670 698 693 642 753 733 618 675 726 729 525 596 608
#  737 754 613 635 678 760 809 595 627 713 731 844]
# ======================
#  ER ~ Column
#  ======================
#  [601 653 584 643 746 609 652 646 604 694 680 572 630 677 664 478 532 546
#  682 700 557 577 638 698 749 553 597 659 655 799]
# ======================
#  ERA ~ Column
#  ======================
#  [3.73 4.07 3.67 3.98 4.64 3.8  4.03 4.05 3.74 4.31 4.24 3.57 3.94 4.16
#  4.14 2.94 3.21 3.36 4.28 4.33 3.43 3.62 4.02 4.41 4.69 3.44 3.72 4.04
#  4.09 5.04]
# ======================
#  CG ~ Column
#  ======================
#  [ 2 11  7  3  0  1  5  6  4]
# ======================
#  SHO ~ Column
#  ======================
#  [ 8 12 10  9  4 13 15 21  7 14 18  6]
# ======================
#  SV ~ Column
#  ======================
#  [56 45 38 37 35 34 48 43 60 40 39 46 28 62 54 50 41 44 47 36]
# ======================
#  E ~ Column
#  ======================
#  [ 88  86  79 101  93  77  95  97 119  85  94 126  96 122 111 116  90 117
#   75  78  92]

# %% [markdown]
# Each columns has unique values

# %%
for i in df.columns:
    print(i,'====>',df[i].nunique())
# Out:
# W ====> 24
# R ====> 28
# AB ====> 29
# H ====> 29
# 2B ====> 22
# 3B ====> 23
# HR ====> 27
# BB ====> 29
# SO ====> 29
# SB ====> 27
# RA ====> 30
# ER ====> 30
# ERA ====> 30
# CG ====> 9
# SHO ====> 12
# SV ====> 20
# E ====> 21

# %% [markdown]
# Each columns has more number of unique values except CG column

# %% [markdown]
# # Stastical analysis

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# * Each columns has 30 rows
#
# *The median is little greater than the mean of each columns there is left skewed data is present in the dataset
#
# *The difference between the max and 75th percentile is little high in some columns we need to check for the outliers in dataset
#
# *The Standard deviation is high in mejority of the columns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# with the help of the heatmap checking for the missing data in the dataset

# %% [markdown]
# # EDA- Process

# %% [markdown]
# Bi-variate analysis

# %%
plt.scatter(x='R',y='W',data=df)
plt.xlabel('R')
plt.ylabel('W')
plt.show()

# %% [markdown]
# R columns is positive coreletion with the W columns ...
# as the Run scored more then the winnning probability is more

# %%
plt.figure(figsize=(15,35))

p=1

for i in df.columns:
    if p<25:
        plt.subplot(8,3,p)
        plt.scatter(x=i,y='W',data=df)
        plt.xlabel(i)
        plt.ylabel('W')
    p+=1
plt.show()

# %% [markdown]
# here we are checking the winning rate of the columns with respect to the values of each column...
#
# * 2B column, means the batter is safely reaching for the second base without calling out ,it has more probability to get win
#
# * HR - the batter complete the circle the bases is more then wins are more
#
# * RA - the avarage runs are increses then there is possiblity of losing the match
#
# * ER as the Earned runs incereses then also winning chances are less

# %%
plt.figure(figsize=(20,20))

p=1

for i in df.columns:
    if p<25:
        plt.subplot(6,4,p)
        sns.kdeplot(data=df[i])
        plt.xlabel(i)
        plt.ylabel('density')
    p+=1
plt.show()

# %% [markdown]
# with the help of KDE plot we are checking probability density of each column

# %%
plt.figure(figsize=(20,6))
sns.heatmap(df.corr(),annot=True,linecolor='black',linewidth=0.2,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# checking for the coreletion of the each column with respect to the wining probability column W
#
# * 'SV column' has highest positive co reletion the wining probability W column
# * R-column,2B-column,BB-column,HR-column,SHO-olumn are also has good positive co reletion with respect to the W-column
# *RA-column,ER-column,ERA-column are highly negative impact on the W_column , we need to remove these columns because
# as in the graph also showing that is a problem of multi colinearity with each other

# %%
sns.countplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='count'>

# %%
df=df.drop(['RA'],axis=1)

# %%
df=df.drop(['ERA'],axis=1)
df=df.drop(['ER'],axis=1)

# %%
plt.figure(figsize=(20,6))
sns.heatmap(df.corr(),annot=True,linecolor='black',linewidth=0.2,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# we are removed highly negative co releted columns from the dataset

# %% [markdown]
# Removing The Outliers from the Dataset

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# 12  0.392433  0.471376  1.432772  1.291077  1.783647  1.002270  0.395247
# 13  0.483244  0.557920  0.400291  0.436688  0.715707  0.904962  1.098383
# 14  1.261625  0.099814  1.208570  0.026106  0.127403  1.430424  0.563574
# 15  1.851896  0.713699  0.465723  0.312089  0.745685  0.749270  0.851220
# 16  1.657301  0.151740  1.656011  1.040693  0.970514  0.418423  0.755338
# 17  1.560004  0.013270  0.364688  1.113079  0.153633  0.126500  0.235444
# 18  1.261625  0.575229  0.523457  0.454487  0.041219  0.262731  0.595534
# 19  1.650815  0.834861  0.789997  0.383288  0.996744  0.418423  0.107601
# 20  0.878921  0.090583  0.154920  0.935081  1.139136  1.391501  0.427208
# 21  0.197838  0.255593  1.274002  0.721484  0.547085  1.780732  0.427208
# 22  0.969732  1.302198  0.768828  0.293103  2.177099  0.846578  1.394552
# 23  1.358922  1.994550  1.389471  0.757084  1.333988  1.294193  2.033766
# 24  1.748112  1.077184  0.183787  0.525687  0.153633  0.554654  1.074945
# 25  1.073516  0.367523  1.894646  1.024080  0.659500  0.515731  0.746815
# 26  0.295136  0.134432  0.703396  1.467888  0.745685  0.749270  0.883181
# 27  0.191352  0.549843  1.915815  1.610286  0.801892  1.625040  0.307888
# 28  0.677839  0.661773  0.855429  1.415675  0.828122  0.457346  0.499652
# 29  1.261625  0.844092  0.804431  1.343289  0.041219  1.722347  0.714854
#
#           BB        SO        SB        CG       SHO        SV         E
# 0   1.534902  2.697630  0.913883  0.539806  0.814629  1.671607  0.461470
# 1   0.536592  0.154878  0.601826  0.539806  0.172800  0.249879  0.607197
# 2   1.139144  0.893982  0.111449  2.772641  0.320914  0.654856  1.117242
# 3   1.160536  0.168602  0.690985  1.300442  0.567771  0.784104  0.485758
# 4   0.251360  0.105866  0.022290  1.300442  0.172800  1.042600  0.607197
# 5   1.798742  0.952796  0.200609  1.300442  0.320914  1.171848  0.461470
# 6   1.513510  0.207812  0.913883  0.171757  1.802057  0.637623  0.097152
# 7   0.910958  0.811641  1.760897  1.275906  0.320914  0.008617  1.262970
# 8   0.590073  0.605790  0.156029  0.907856  0.172800  2.188598  0.048576
# 9   0.158660  0.982204  0.557246  0.171757  0.320914  0.396360  0.194303
# 10  0.604334  0.148997  0.780144  0.564343  0.567771  0.249879  1.797303
# 11  0.301276  1.409590  1.671738  0.564343  0.419657  0.525608  0.680061
# 12  0.607900  0.962599  1.404260  0.539806  0.172800  0.379127  0.097152
# 13  0.158660  0.860654  0.646405  0.932393  0.172800  0.249879  0.024288
# 14  0.105179  1.266474  0.245188  0.564343  0.913371  1.947335  2.307348
# 15  0.657815  0.184286  0.646405  0.907856  0.913371  2.447094  0.121439
# 16  0.144398  0.723420  0.646405  1.275906  0.419657  1.413111  2.015894
# 17  1.745261  2.644696  0.512666  0.932393  2.394514  0.637623  1.214394
# 18  1.017920  0.497964  0.022290  0.907856  1.061486  0.396360  1.578712
# 19  0.479546  0.066657  2.251273  0.539806  0.814629  1.042600  0.315742
# 20  0.336930  0.409742  1.448839  0.907856  0.666514  0.896119  0.461470
# 21  1.246105  0.939073  1.181361  0.196293  0.419657  0.267112  0.315742
# 22  1.677518  0.962599  1.270521  1.275906  0.172800  1.042600  1.262970
# 23  0.033871  1.384104  0.646405  0.171757  0.320914  0.120631  0.315742
# 24  1.463595  0.252903  0.200609  0.907856  1.061486  1.042600  1.651576
# 25  1.673953  0.096064  1.092202  0.932393  2.394514  0.508375  1.408697
# 26  0.215706  0.874377  0.423507  1.300442  1.653943  0.267112  1.190106
# 27  0.372584  0.625395  2.162114  0.907856  0.172800  0.120631  0.607197
# 28  0.768343  0.772432  0.066870  0.907856  1.308343  0.267112  0.170015
# 29  1.445768  0.341125  0.601826  0.196293  1.802057  0.913352  0.048576

# %% [markdown]
# with the ZSCORE method removing the outliers present in the dataset

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %% [markdown]
# setting threshold to 3,because 99.9% of the data is located in the 3 standard deviations

# %%
print(z.iloc[5][1])
print(z.iloc[5][5])
# Out:
# 3.5096470447193067
# 1.3915009787854262

# %% [markdown]
# only one point as outliers , except all are in 3 deviations only

# %%
df1=df[(z<3).all(axis=1)]

# %% [markdown]
# saving the data in the new dataset df1 , after the removal of the outliers

# %%
print(df.shape)
print(df1.shape)
# Out:
# (30, 14)
# (29, 14)

# %% [markdown]
# we can see here the point with outlier is removed from the dataset df

# %% [markdown]
# Checking for the skewness of dataset

# %%
df1.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# the ideal range for the skewness is -0.5 to 0.5 , some columns like CG and E are having more then 0.5 , we need to remove the skewness from these columns

# %%
df1['E']=np.cbrt(df1['E'])
df1['CG']=np.cbrt(df1['CG'])

# %%
df1.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# CG    -1.013981
# SHO    0.526943
# SV     0.627480
# E      0.671748
# dtype: float64

# %% [markdown]
# now we can see the skewness is removed from these columns

# %%
plt.figure(figsize=(15,20))

p=1

for i in df1.columns:
    if p<20:
        plt.subplot(6,4,p)
        sns.distplot(df1[i])
        plt.xlabel(i)
        plt.ylabel('--')
    p+=1
plt.show()

# %% [markdown]
# With the help of distplot , checking graphical analysis of for skewness present in the each columns

# %% [markdown]
# Separing the Dependent and Independent variable as x and y for modelling

# %%
x=df1.iloc[:,1:]
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB        CG  SHO  SV         E
# 0   724  5575  1497  300  42  139  383   973  104  1.259921    8  56  4.447960
# 1   696  5467  1349  277  44  156  439  1264   70  1.259921   12  45  4.414005
# 2   669  5439  1395  303  29  141  533  1157   86  2.223980   10  38  4.290840
# 3   622  5533  1381  260  27  136  404  1231   68  1.912931    9  37  4.657010
# 4   689  5605  1515  289  49  151  455  1259   83  1.912931   12  35  4.414005
# 6   764  5567  1397  272  19  212  554  1227   63  1.442250    4  48  4.530655
# 7   713  5485  1370  246  20  217  418  1331   44  0.000000   10  43  4.254321
# 8   644  5485  1383  278  32  167  436  1310   87  1.000000   12  60  4.562903
# 9   748  5640  1495  294  33  161  478  1148   71  1.442250   10  40  4.594701
# 10  751  5511  1419  279  32  172  503  1233  101  1.709976    9  45  4.918685
# 11  729  5459  1363  278  26  230  486  1392  121  1.709976   13  39  4.396830
# 12  661  5417  1331  243  21  176  435  1150   52  1.259921   12  46  4.530655
# 13  656  5544  1379  262  22  198  478  1336   69  1.817121   12  45  4.546836
# 14  694  5600  1405  277  46  146  475  1119   78  1.709976   15  28  5.013298
# 15  647  5484  1386  288  39  137  506  1267   69  1.000000   15  62  4.578857
# 16  697  5631  1462  292  27  140  461  1322   98  0.000000   13  54  4.959676
# 17  689  5491  1341  272  30  171  567  1518   95  1.817121   21  48  4.805896
# 18  655  5480  1378  274  34  145  412  1299   84  1.000000    7  40  4.876999
# 19  640  5571  1382  257  27  167  496  1255  134  1.259921    8  35  4.481405
# 20  683  5527  1351  295  17  177  488  1290   51  1.000000   14  50  4.447960
# 21  703  5428  1363  265  13  177  539  1344   57  1.587401   13  41  4.481405
# 22  613  5463  1420  236  40  120  375  1150  112  0.000000   12  35  4.254321
# 23  573  5420  1361  251  18  100  471  1107   69  1.442250   10  44  4.481405
# 24  626  5529  1374  272  37  130  387  1274   88  1.000000    7  35  4.890973
# 25  667  5385  1346  263  26  187  563  1258   59  1.817121   21  47  4.217163
# 26  696  5565  1486  288  39  136  457  1159   93  1.912931   18  41  4.272659
# 27  720  5649  1494  289  48  154  490  1312  132  1.000000   12  44  4.414005
# 28  650  5457  1324  260  36  148  426  1327   82  1.000000    6  41  4.514357
# 29  737  5572  1479  274  49  186  388  1283   97  1.587401    4  36  4.562903

# %% [markdown]
# separating the independent columns as x

# %%
y=df1['W']
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %% [markdown]
# separing the target columns or dependent variable as y

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.959398  0.830084  1.738306  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -0.938698  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253 -0.106656  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -0.359886 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  2.063888  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535 -0.070480 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345 -0.558853 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345 -0.323710  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  1.702131  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310  0.327453  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380 -0.685468  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514 -1.264279 -1.802414 -1.068901  0.506228 -0.569402
# 12 -0.566355  0.390081 -0.396062 -0.682763 -0.969865  1.262607  0.230197
# 13  0.286272  1.184926  0.074223  0.201171  1.406988 -0.525197  0.174411
# 14 -0.768292 -0.461539 -0.269447  0.849390  0.713739 -0.834625  0.750867
# 15  0.353585  1.624929  1.105231  1.085106 -0.474688 -0.731482 -0.085923
# 16  0.174084 -0.362183 -1.083401 -0.093474 -0.177581  0.334324  1.885182
# 17 -0.588792 -0.518313 -0.414150  0.024384  0.218561 -0.559578 -0.997094
# 18 -0.925355  0.773310 -0.341798 -0.977408 -0.474688  0.196801  0.564913
# 19  0.039459  0.148789 -0.902522  1.261893 -1.465043  0.540609  0.416151
# 20  0.488210 -1.256383 -0.685468 -0.505976 -1.861185  0.540609  1.364512
# 21 -1.531169 -0.759605  0.345541 -2.214917  0.812774 -1.419099 -1.685122
# 22 -2.428670 -1.369933 -0.721643 -1.330982 -1.366007 -2.106716  0.100030
# 23 -1.239481  0.177176 -0.486501 -0.093474  0.515668 -1.075291 -1.461978
# 24 -0.319542 -1.866711 -0.992961 -0.623834 -0.573723  0.884418  1.810800
# 25  0.331147  0.688148  1.539340  0.849390  0.713739 -0.869006 -0.160305
# 26  0.869648  1.880415  1.684043  0.908319  1.605059 -0.250150  0.453341
# 27 -0.700980 -0.844767 -1.390895 -0.800621  0.416632 -0.456435 -0.736760
# 28  1.251086  0.787503  1.412725  0.024384  1.704094  0.850037 -1.443382
#
#           SO        SB        CG       SHO        SV         E
# 0  -2.727623  0.905953 -0.094672 -0.813262  1.643157 -0.448230
# 1   0.121896 -0.585315 -0.094672  0.159299  0.211006 -0.604643
# 2  -0.925866  0.116458  1.615608 -0.326982 -0.700362 -1.171994
# 3  -0.201246 -0.673037  1.063794 -0.570122 -0.830557  0.514746
# 4   0.072935 -0.015124  1.063794  0.159299 -1.090948 -0.604643
# 5  -0.240414 -0.892341  0.228786 -1.785822  0.601593 -0.067301
# 6   0.777970 -1.725697 -2.329822 -0.326982 -0.049384 -1.340220
# 7   0.572335  0.160319 -0.555782  0.159299  2.163939  0.081247
# 8  -1.013995 -0.541454  0.228786 -0.326982 -0.439971  0.227724
# 9  -0.181661  0.774370  0.703744 -0.570122  0.211006  1.720140
# 10  1.375292  1.651587  0.703744  0.402439 -0.570166 -0.683760
# 11 -0.994411 -1.374810 -0.094672  0.159299  0.341202 -0.067301
# 12  0.826931 -0.629176  0.893823  0.159299  0.211006  0.007236
# 13 -1.297968 -0.234429  0.703744  0.888719 -2.002317  2.155971
# 14  0.151272 -0.629176 -0.555782  0.888719  2.424329  0.154740
# 15  0.689841  0.642788 -2.329822  0.402439  1.382766  1.908962
# 16  2.609104  0.511205  0.893823  2.347560  0.601593  1.200582
# 17  0.464621  0.028736 -0.555782 -1.056402 -0.439971  1.528116
# 18  0.033766  2.221778 -0.094672 -0.813262 -1.090948 -0.294169
# 19  0.376492 -1.418671 -0.555782  0.645579  0.861984 -0.448230
# 20  0.905268 -1.155506  0.486291  0.402439 -0.309775 -0.294169
# 21 -0.994411  1.256840 -2.329822  0.159299 -1.090948 -1.340220
# 22 -1.415474 -0.629176  0.228786 -0.326982  0.080811 -0.294169
# 23  0.219817  0.204180 -0.555782 -1.056402 -1.090948  1.592488
# 24  0.063143 -1.067784  0.893823  2.347560  0.471397 -1.511384
# 25 -0.906281  0.423484  1.063794  1.618139 -0.309775 -1.255748
# 26  0.591919  2.134056 -0.555782  0.159299  0.080811 -0.604643
# 27  0.738802 -0.058985 -0.555782 -1.299542 -0.309775 -0.142374
# 28  0.307947  0.598927  0.486291 -1.785822 -0.960753  0.081247

# %% [markdown]
# using the standardscaler to standardize the values with mean equal to zero and standard deviation to -1 to +1

# %% [markdown]
# # Checking for Multi co linearity of each column

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i)
                  for i in range(len(x.columns))]
vif['VIF Features']=x.columns
vif
# Out:
#     VIF Values VIF Features
# 0     6.156148            R
# 1     4.521118           AB
# 2     6.596497            H
# 3     3.029862           2B
# 4     2.823985           3B
# 5     6.329697           HR
# 6     3.261843           BB
# 7     2.277841           SO
# 8     1.609418           SB
# 9     2.269973           CG
# 10    1.690051          SHO
# 11    1.790360           SV
# 12    2.029434            E

# %% [markdown]
# we can there is no multi colinearity present beacuse the vif value is in between the -10 to +10 ,its accptable range

# %%
y.value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 97     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 95     1
# 98     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 79     1
# Name: W, dtype: int64

# %% [markdown]
# Checking for the value present in the target columns,
#
# since the values contineous we need to choose the regression model for modelling the dataset

# %% [markdown]
# # Modelling

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %% [markdown]
# import LinearRegression model and nessasary metrics for prediction such as r2_score,mse,and mae

# %%
maxAccu=0
maxRs=0
for i in range(1,29):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
        
print('Maxaccuracy is ',maxAccu,'at random state',maxRs)
# Out:
# Maxaccuracy is  0.6810868280868831 at random state 28

# %% [markdown]
# checking best random state to perform the model well

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRs)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor,BaggingRegressor
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor

# %% [markdown]
# importing all the other nessasary lybraries for the Regression model

# %%
print('LinearRegression')
predlr=lr.predict(x_test)
predlr_train=lr.predict(x_train)
print('R2 score on test data',r2_score(y_test,predlr)*100)
print('R2 score on train data',r2_score(y_train,predlr_train)*100)
print('Mean sqaured error',mean_squared_error(y_test,predlr))
print('Mean absolute error',mean_absolute_error(y_test,predlr))
# Out:
# LinearRegression
# R2 score on test data 68.10868280868831
# R2 score on train data 85.7294164198473
# Mean sqaured error 31.426727632228385
# Mean absolute error 4.6535402691229075

# %% [markdown]
# with LinearRegression the r2_score is 75%

# %%
print('DecisionTreeRegressor')
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_dtr_train=dtr.predict(x_train)
print('R2 score on test data ',r2_score(y_test,pred_dtr)*100)
print('R2 score on train data',r2_score(y_train,pred_dtr_train)*100)
print('Mean absolute error ',mean_absolute_error(y_test,pred_dtr))
print('Mean squared error',mean_squared_error(y_test,pred_dtr))
# Out:
# DecisionTreeRegressor
# R2 score on test data  36.74517664745679
# R2 score on train data 100.0
# Mean absolute error  6.333333333333333
# Mean squared error 62.333333333333336

# %% [markdown]
# DecisionTreeclassifier is showing underfitting the this dataset

# %%
print('SVR')
svr=SVR()
svr.fit(x_train,y_train)
predsvr=svr.predict(x_test)
predsvr_train=svr.predict(x_train)
print('R2 score on test data',r2_score(y_test,predsvr)*100)
print('R2 score on train data',r2_score(y_train,predsvr_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,predsvr))
print('Mean squared error',mean_squared_error(y_test,predsvr))
# Out:
# SVR
# R2 score on test data 8.876768437241333
# R2 score on train data 16.617181437548044
# Mean absolute error 8.371493033431166
# Mean squared error 89.79575732517775

# %% [markdown]
# support vector also not performing well for this dataset

# %%
print('GradientBoostingRegressor')
gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)
predgb=gb.predict(x_test)
predgb_train=gb.predict(x_train)
print('R2 score on test data',r2_score(y_test,predgb)*100)
print('R2 score on train data',r2_score(y_train,predgb_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,predgb))
print('Mean squared error',mean_squared_error(y_test,predgb))
print('\n')

print('AdaBoostRegressor')
ab=AdaBoostRegressor()
ab.fit(x_train,y_train)
predab=ab.predict(x_test)
predab_train=ab.predict(x_train)
print('R2 score on test data',r2_score(y_test,predab)*100)
print('R2 score on train data',r2_score(y_train,predab_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,predab))
print('Mean squared error',mean_squared_error(y_test,predab))
print('\n')

print('BaggingRegressor')
bg=BaggingRegressor()
bg.fit(x_train,y_train)
predbg=bg.predict(x_test)
predbg_train=bg.predict(x_train)
print('R2 score on test data',r2_score(y_test,predbg)*100)
print('R2 score on train data',r2_score(y_train,predbg_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,predbg))
print('Mean squared error',mean_squared_error(y_test,predbg))
# Out:
# GradientBoostingRegressor
# R2 score on test data 57.94830650355293
# R2 score on train data 99.99999519564781
# Mean absolute error 5.405227843789289
# Mean squared error 41.43908857884452
#
#
# AdaBoostRegressor
# R2 score on test data 29.52491674862546
# R2 score on train data 98.40725649803198
# Mean absolute error 7.466490299823633
# Mean squared error 69.44840919907057
#
#
# BaggingRegressor
# R2 score on test data 63.40804309696817
# R2 score on train data 91.38117139102684
# Mean absolute error 4.87777777777778
# Mean squared error 36.0588888888889

# %% [markdown]
# GradientBoosting,AdaBoost and Bagging regressor also showing the underfitting beacuse the dataset is too small

# %%
print('RandomForestRegressor')
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
predrf_train=rf.predict(x_train)
print('R2 score on test data',r2_score(y_test,predrf)*100)
print('R2 score on train data',r2_score(y_train,predrf_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,predrf))
print('Mean squared error',mean_squared_error(y_test,predrf))
print('\n')

print('ExtraTreesRegressor')
et=ExtraTreesRegressor()
et.fit(x_train,y_train)
predet=et.predict(x_test)
predet_train=et.predict(x_train)
print('R2 score on test data',r2_score(y_test,predet)*100)
print('R2 score on train data',r2_score(y_train,predet_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,predet))
print('Mean squared error',mean_squared_error(y_test,predet))
# Out:
# RandomForestRegressor
# R2 score on test data 46.88914181909294
# R2 score on train data 90.217247043364
# Mean absolute error 6.370000000000001
# Mean squared error 52.337144444444476
#
#
# ExtraTreesRegressor
# R2 score on test data 47.024265848158365
# R2 score on train data 100.0
# Mean absolute error 6.116666666666666
# Mean squared error 52.20398888888889

# %% [markdown]
# same problem with RandomForest and ExtraTrees Regressor also

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet

# %%
print('Lasso')
ls=Lasso(alpha=0.1)
ls.fit(x_train,y_train)
predls=ls.predict(x_test)
predls_train=ls.predict(x_train)
print('R2 score on test data',r2_score(y_test,predls)*100)
print('R2 score on train data ',r2_score(y_train,predls_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,predls))
print('Mean squared error',mean_squared_error(y_test,predls))
print('\n')

print('Ridge')
rd=Ridge(alpha=0.1)
rd.fit(x_train,y_train)
predrd=rd.predict(x_test)
predrd_train=rd.predict(x_train)
print('R2 score on test data',r2_score(y_test,predrd)*100)
print('R2 score on train data',r2_score(y_train,predrd_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,predrd))
print('Mean squared error',mean_squared_error(y_test,predrd))
print('\n')

print('ElasticNet')
e=ElasticNet(alpha=0.1)
e.fit(x_train,y_train)
prede=e.predict(x_test)
prede_train=e.predict(x_train)
print('R2 score on test data',r2_score(y_test,prede)*100)
print('R2 score on train data',r2_score(y_train,prede_train)*100)
print('Mean absolue error',mean_absolute_error(y_test,prede))
print('Mean squared error',mean_squared_error(y_test,prede))
# Out:
# Lasso
# R2 score on test data 74.25709311107379
# R2 score on train data  85.34301708970773
# Mean absolute error 4.157572304793498
# Mean squared error 25.367886763877664
#
#
# Ridge
# R2 score on test data 68.34115243051053
# R2 score on train data 85.70734236148716
# Mean absolute error 4.585428730703659
# Mean squared error 31.19764460489692
#
#
# ElasticNet
# R2 score on test data 67.00894021225636
# R2 score on train data 84.75593336469971
# Mean absolue error 4.687446952521869
# Mean squared error 32.51044928713206

# %% [markdown]
# with lasso,ridge and elasticnet regressor ElasticNet is performing well with r2_score of 80%

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# to check the over fitting and under fitting of the dataset using the cross validation score

# %%
print('LinearRegression')
sclr=cross_val_score(ab,x_train,y_train,cv=5)
print('Score',sclr*100)
print('Mean score',sclr.mean()*100)
# Out:
# LinearRegression
# Score [ 39.62980541  49.62406015 -32.7142435  -44.78607653   1.19941351]
# Mean score 2.590591808688094

# %% [markdown]
# with LinearRegression r2 score is just 20%

# %%
print('ElasticNet')
scoreel=cross_val_score(et,x_train,y_train,cv=2)
print('Score',scoreel*100)
print('Mean Score',scoreel.mean()*100)
print('\n')

print('Ridge')
scorerg=cross_val_score(rd,x_train,y_train,cv=2)
print('Score',scorerg*100)
print('Mean Score',scorerg.mean()*100)
print('\n')

print('Lasso')
scorels=cross_val_score(ls,x_train,y_train,cv=2)
print('Score',scorels*100)
print('Mean Score',scorels.mean()*100)
print('\n')

print('AdaBoost')
scoreab=cross_val_score(ab,x_train,y_train,cv=2)
print('Score',scoreab*100)
print('Mean Score',scoreab.mean()*100)
print('\n')

print('ExtraTrees')
scoreet=cross_val_score(et,x,y,cv=2)
print('Score',scoreet*100)
print('Mean Score',scoreet.mean()*100)
print('\n')

print('Bagging')
scorebg=cross_val_score(bg,x,y,cv=2)
print('Score',scorebg*100)
print('Mean Score',scorebg.mean()*100)
print('\n')

print('GradinetBoosting')
scoregb=cross_val_score(gb,x,y,cv=2)
print('Score',scoregb*100)
print('Mean Score',scoregb.mean()*100)
print('\n')

print('DecisionTree')
scoredtc=cross_val_score(dtr,x_train,y_train,cv=2)
print('Score',scoredtc*100)
print('Mean Score',scoredtc.mean()*100)
print('\n')

print('Support vector')
scoresvr=cross_val_score(svr,x_train,y_train,cv=2)
print('Score',scoresvr*100)
print('Mean Score',scoresvr.mean()*100)
print('\n')

print('RandomForest')
scorerf=cross_val_score(rf,x,y,cv=2)
print('Score',scorerf*100)
print('Mean Score',scorerf.mean()*100)
print('\n')
# Out:
# ElasticNet
# Score [35.24153435 43.38771754]
# Mean Score 39.31462594274265
#
#
# Ridge
# Score [-115.64564484 -154.67308793]
# Mean Score -135.15936638673622
#
#
# Lasso
# Score [-63.245692  -90.7749876]
# Mean Score -77.01033980188038
#
#
# AdaBoost
# Score [-6.25101264 13.51827061]
# Mean Score 3.6336289877993755
#
#
# ExtraTrees
# Score [ 0.22711172 25.72435812]
# Mean Score 12.97573491727081
#
#
# Bagging
# Score [-89.25319088   8.26198083]
# Mean Score -40.49560502421715
#
#
# GradinetBoosting
# Score [-211.45420201   22.4680415 ]
# Mean Score -94.49308025222729
#
#
# DecisionTree
# Score [ -5.31432275 -56.06871932]
# Mean Score -30.69152103481253
#
#
# Support vector
# Score [-3.69167433 -0.40768362]
# Mean Score -2.049678972999669
#
#
# RandomForest
# Score [-84.62986519   3.94730322]
# Mean Score -40.341280985194196

# %% [markdown]
# after the cross validation ElasticNet is best  performing model

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {"max_iter": [1, 5, 10],
             "alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100],
            "l1_ratio": np.arange(0.0, 1.0, 0.1)}

# %%
gscv=GridSearchCV(ElasticNet(),parameters,cv=5)
gscv.fit(x_train,y_train)
gscv.best_params_
# Out:
# {'alpha': 1, 'l1_ratio': 0.9, 'max_iter': 10}

# %%
model=ElasticNet(max_iter=10,alpha=1,l1_ratio=0.9)

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('R2 Score',r2_score(y_test,pred)*100)
print('MSE =',mean_squared_error(y_test,pred))
print('MAE =',mean_absolute_error(y_test,pred))
# Out:
# R2 Score 70.04110580857395
# MSE = 29.522455979748493
# MAE = 4.656028563421913

# %%
import pickle
file='Base_ball'
pickle.dump(model,open(file,'wb'))

# %% [markdown]
# with the help of pickle lybrari saving the model

# %%
final=pickle.load(open('Base_ball','rb'))
final.score(x_test,y_test)*100
# Out:
# 70.04110580857395
